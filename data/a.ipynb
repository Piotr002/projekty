# %%
import pandas as pd
from ggplot import *

# %%
df = pd.read_csv("czas/czas18.csv")
df.head()
# Out:
#            czas  Bielany - pwr
# 0  29.08, 15:43             36
# 1  29.08, 15:46             37
# 2  29.08, 15:49             38
# 3  29.08, 15:52             39
# 4  29.08, 15:55             40

# %%
df.tail()
# Out:
#             czas  Bielany - pwr
# 39  29.08, 17:46             34
# 40  29.08, 17:49             33
# 41  29.08, 17:53             33
# 42  29.08, 17:56             34
# 43  29.08, 17:59             33

# %%
print(ggplot(df, aes("czas", "Bielany - pwr")) +
      geom_line())
# Out:
# <ggplot: (131938346990)>

# %%
print(ggplot(mtcars, aes('mpg', 'qsec')) + \
geom_point(colour='steelblue') + \
scale_x_continuous(breaks=[10,20,30], \
labels=["horrible", "ok", "awesome"]))
# Out:
# <ggplot: (131938457567)>

# %%
import numpy as np
import random as rd
import time

# %%
start = time.time()
for i in range(100):
    rd.sample(range(1, 1000000), k=10000)
time.time()-start
# Out:
# 20.381184339523315

# %%
rd.choices(range(1, 10), k=11)
# Out:
# [5, 2, 8, 8, 7, 7, 1, 1, 2, 2, 2]
