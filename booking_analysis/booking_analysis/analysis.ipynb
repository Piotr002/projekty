# %%
import pandas as pd
import ast

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("processed_data.csv", index_col=0)
data.head()
# Out:
#         city                                    hotel_name  people_number  \
# 1  Barcelona  ABaC Restaurant Hotel Barcelona GL Monumento              1
# 2  Barcelona                        Sonder La Casa del Sol              1
# 3  Barcelona                 Travelodge Barcelona Poblenou              1
# 4  Barcelona                       Catalonia La Maquinista              1
# 5  Barcelona                        Unite Hostel Barcelona              1
#
#    days_number   price  staff  amenities  cleanliness  comfort  \
# 1            1  1494.0    9.5        9.2          9.5      9.5
# 2            1   620.0    7.8        7.9          8.5      8.4
# 3            1   265.0    8.2        7.0          7.9      7.6
# 4            1   369.0    9.1        8.6          9.0      8.9
# 5            1   105.0    8.4        8.4          8.4      8.3
#
#    value_for_money  location  free_wifi  average_opinion
# 1              8.6       8.9        8.8              9.2
# 2              7.5       9.2        8.3              7.8
# 3              7.2       8.2        NaN              7.3
# 4              8.1       8.1        8.3              8.5
# 5              8.2       8.7        8.9              8.2

# %% [markdown]
# ## Amenities

# %%
with open("amenities.dat") as file:
    amenities = ast.literal_eval(file.read())

# %%
amenities
# Out:
# [{'Najpopularniejsze udogodnienia': ['Kryty basen',
#    'centrum fitness',
#    'transfer lotniskowy',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'szlafrok',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'płatne kanały'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'winda',
#    'klimatyzacja',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'Wi-Fi',
#    'parking na miejscu',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy', 'ręczniki', 'prywatna łazienka', 'toaleta'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['berberyjski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski',
#    'gruziński',
#    'rosyjski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy', 'prywatna łazienka', 'toaleta', 'prysznic'],
#   'Języki': ['angielski', 'hiszpański', 'chorwacki', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'przechowalnia bagażu',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '4 restauracje',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski',
#    'koreański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor',
#    'płatne kanały'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'obsługa pokoju',
#    '3 restauracje',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['arabski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'hindi',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie'],
#   'Łazienka': ['papier toaletowy',
#    'toaleta',
#    'suszarka do włosów',
#    'prysznic'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'włoski', 'rosyjski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'radio',
#    'telefon'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['2 baseny',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'spa i centrum odnowy biologicznej',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '3 restauracje',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'kapcie',
#    'toaleta',
#    'szlafrok',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'centrum fitness',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'lokalizacja przy samej plaży',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'dodatkowa łazienka',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'winda',
#    'klimatyzacja',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'bezpłatny parking',
#    'całodobowa recepcja',
#    'winda',
#    'klimatyzacja',
#    'ogrzewanie',
#    'przechowalnia bagażu',
#    'wanna z hydromasażem / jacuzzi'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'transfer lotniskowy',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'winda',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['2 baseny',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '3 restauracje',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'kapcie',
#    'toaleta',
#    'szlafrok',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'transfer lotniskowy',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'parking',
#    'całodobowa recepcja',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'szlafrok',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja (tymczasowo niedostępne)',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar (tymczasowo niedostępne)',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'winda',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'lokalizacja przy samej plaży',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'dodatkowa łazienka',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '4 restauracje',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor',
#    'płatne kanały'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Znakomite śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'centrum fitness',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'winda',
#    'klimatyzacja',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'bezpłatny parking',
#    'całodobowa recepcja',
#    'winda',
#    'klimatyzacja',
#    'ogrzewanie',
#    'przechowalnia bagażu',
#    'wanna z hydromasażem / jacuzzi'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'Wi-Fi',
#    'parking na miejscu',
#    'transfer lotniskowy',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy', 'ręczniki', 'prywatna łazienka', 'toaleta'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['berberyjski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski',
#    'gruziński',
#    'rosyjski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'transfer lotniskowy',
#    'pokoje rodzinne',
#    'winda',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['2 baseny',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '3 restauracje',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bidet',
#    'kapcie',
#    'toaleta',
#    'szlafrok',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'lokalizacja przy samej plaży',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'dodatkowa łazienka',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'bezpłatne Wi-Fi',
#    'parking na miejscu',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'przechowalnia bagażu'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja (tymczasowo niedostępne)',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar (tymczasowo niedostępne)',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'prywatna łazienka',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'obsługa pokoju',
#    '3 restauracje',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['arabski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'hindi',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'parking',
#    'transfer lotniskowy',
#    'całodobowa recepcja',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'szlafrok',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'bar',
#    'winda',
#    'pralnia',
#    'klimatyzacja',
#    'ogrzewanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski']},
#  {'Najpopularniejsze udogodnienia': ['2 baseny (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '4 restauracje (3 otwarte)',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['prywatna łazienka', 'toaleta', 'bezpłatny zestaw kosmetyków'],
#   'Media/Technologia': ['kanały kablowe', 'telewizor'],
#   'Języki': ['arabski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski',
#    'holenderski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'winda',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'taras',
#    'bar',
#    'winda',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['2 baseny (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '4 restauracje (3 otwarte)',
#    'parking na miejscu',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['prywatna łazienka', 'toaleta', 'bezpłatny zestaw kosmetyków'],
#   'Media/Technologia': ['kanały kablowe', 'telewizor'],
#   'Języki': ['arabski',
#    'kataloński',
#    'niemiecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'włoski',
#    'holenderski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'obsługa pokoju',
#    'bezpłatny parking',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'winda',
#    'klimatyzacja',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telewizor'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['prywatny parking',
#    'taras',
#    'bar',
#    'klimatyzacja',
#    'Śniadanie'],
#   'Łazienka': ['ręczniki'],
#   'Media/Technologia': ['telewizor z płaskim ekranem'],
#   'Języki': ['arabski', 'kataloński', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen (tymczasowo niedostępne)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'restauracja',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Języki': ['kataloński', 'angielski', 'hiszpański', 'francuski']},
#  {'Najpopularniejsze udogodnienia': ['Odkryty basen',
#    'pokoje dla niepalących',
#    'centrum fitness',
# ...
#   'Łazienka': ['ręczniki', 'toaleta', 'prysznic'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'całodobowa recepcja',
#    'ogrzewanie',
#    'winda',
#    'ogród',
#    'codzienne sprzątanie',
#    'przechowalnia bagażu',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'węgierski', 'rumuński']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'ogrzewanie',
#    'przechowalnia bagażu',
#    'część przeznaczona dla palących',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['kanały satelitarne', 'telewizor'],
#   'Języki': ['angielski', 'węgierski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'parking',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'pralnia'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'wspólna toaleta',
#    'toaleta',
#    'wspólna łazienka',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['serwis z filmami online (np. Netflix)',
#    'telewizor z płaskim ekranem',
#    'odtwarzacz wideo',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'bar',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'radio',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'bezpłatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'ogród',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telefon', 'telewizor'],
#   'Języki': ['niemiecki', 'angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy (bezpłatny)',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'bezpłatne Wi-Fi',
#    'bezpłatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'ogród',
#    'klimatyzacja',
#    'część przeznaczona dla palących'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'pralnia'],
#   'Łazienka': ['papier toaletowy',
#    'toaleta',
#    'suszarka do włosów',
#    'prysznic'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    '2 restauracje',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['niemiecki',
#    'grecki',
#    'angielski',
#    'hiszpański',
#    'francuski',
#    'węgierski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'codzienne sprzątanie',
#    'pralnia',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem', 'telewizor'],
#   'Języki': ['niemiecki', 'angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'bezpłatny parking',
#    'taras',
#    'ogrzewanie',
#    'ogród',
#    'pralnia',
#    'przechowalnia bagażu',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'wanna lub prysznic',
#    'toaleta',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'francuski', 'węgierski']},
#  {'Najpopularniejsze udogodnienia': ['Kryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '2 restauracje',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['szlafrok', 'suszarka do włosów'],
#   'Języki': ['niemiecki', 'angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'prywatny parking',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'ogród'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['transfer lotniskowy',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    '2 restauracje',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['serwis z filmami online (np. Netflix)',
#    'telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'ogrzewanie',
#    'klimatyzacja',
#    'część przeznaczona dla palących'],
#   'Łazienka': ['wspólna łazienka'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'transfer lotniskowy',
#    'restauracja',
#    'udogodnienia dla niepełnosprawnych',
#    'obsługa pokoju',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Fantastyczne śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski', 'hiszpański', 'francuski', 'węgierski', 'włoski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatny parking',
#    'bezpłatne Wi-Fi',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['serwis z filmami online (np. Netflix)',
#    'telewizor z płaskim ekranem',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'transfer lotniskowy',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'ogród',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'wanna'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'taras',
#    'ogrzewanie',
#    'ogród',
#    'codzienne sprzątanie',
#    'pralnia',
#    'przechowalnia bagażu'],
#   'Łazienka': ['papier toaletowy', 'toaleta', 'prysznic'],
#   'Języki': ['angielski', 'hiszpański']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'parking',
#    'bezpłatne Wi-Fi',
#    'ogrzewanie',
#    'codzienne sprzątanie',
#    'pralnia'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'wspólna toaleta',
#    'toaleta',
#    'wspólna łazienka',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['serwis z filmami online (np. Netflix)',
#    'telewizor z płaskim ekranem',
#    'odtwarzacz wideo',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['Kryty basen',
#    'spa i centrum odnowy biologicznej',
#    'pokoje dla niepalących',
#    'centrum fitness',
#    'restauracja',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'zestaw do parzenia kawy i herbaty we wszystkich pokojach',
#    'bar',
#    'Bardzo dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'kapcie',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'szlafrok',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telefon',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'transfer lotniskowy',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'ręczniki / pościel (dostępne za dodatkową opłatą)',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'transfer lotniskowy',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'winda',
#    'ogród'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'ogrzewanie',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Media/Technologia': ['serwis z filmami online (np. Netflix)',
#    'telewizor z płaskim ekranem'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'transfer lotniskowy',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'ogrzewanie',
#    'przechowalnia bagażu',
#    'część przeznaczona dla palących',
#    'Śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'prywatna łazienka',
#    'toaleta',
#    'suszarka do włosów',
#    'wanna',
#    'prysznic'],
#   'Media/Technologia': ['kanały satelitarne', 'telewizor'],
#   'Języki': ['angielski', 'węgierski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'udogodnienia dla niepełnosprawnych',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'całodobowa recepcja',
#    'taras',
#    'ogrzewanie',
#    'bar',
#    'Dobre śniadanie'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'bezpłatny zestaw kosmetyków',
#    'suszarka do włosów',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały satelitarne',
#    'radio',
#    'telefon',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'francuski', 'węgierski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'bezpłatne Wi-Fi',
#    'pokoje rodzinne',
#    'ogrzewanie',
#    'klimatyzacja',
#    'część przeznaczona dla palących'],
#   'Łazienka': ['wspólna łazienka'],
#   'Języki': ['angielski']},
#  {'Najpopularniejsze udogodnienia': ['pokoje dla niepalących',
#    'prywatny parking',
#    'bezpłatne Wi-Fi',
#    'całodobowa recepcja',
#    'ogrzewanie',
#    'winda',
#    'ogród',
#    'codzienne sprzątanie',
#    'przechowalnia bagażu',
#    'klimatyzacja'],
#   'Łazienka': ['papier toaletowy',
#    'ręczniki',
#    'wanna lub prysznic',
#    'prywatna łazienka',
#    'toaleta',
#    'prysznic'],
#   'Media/Technologia': ['telewizor z płaskim ekranem',
#    'kanały kablowe',
#    'kanały satelitarne',
#    'telewizor'],
#   'Języki': ['niemiecki', 'angielski', 'węgierski', 'rumuński']},
#  ...]
